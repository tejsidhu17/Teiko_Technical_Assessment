# %%
import helper_functions as hf
import pandas as pd

hf.analyze_miraclib_response()
# Out:
# ...
# STATISTICAL ANALYSIS: Melanoma Patients on Miraclib (PBMC Samples)
# Comparing Cell Population Frequencies: Responders vs Non-Responders
# ...
# b_cell:
#   Responders:     Mean = 9.80%, Median = 9.43%
#   Non-Responders: Mean = 10.00%, Median = 9.79%
#   Difference:     -0.20%
#   p-value:        0.0557 ns
#
# cd8_t_cell:
#   Responders:     Mean = 24.88%, Median = 24.73%
#   Non-Responders: Mean = 24.94%, Median = 24.60%
#   Difference:     -0.06%
#   p-value:        0.6392 ns
#
# cd4_t_cell:
#   Responders:     Mean = 30.54%, Median = 30.22%
#   Non-Responders: Mean = 29.90%, Median = 29.66%
#   Difference:     0.64%
#   p-value:        0.0134 *
#
# nk_cell:
#   Responders:     Mean = 14.84%, Median = 14.51%
#   Non-Responders: Mean = 15.07%, Median = 14.80%
#   Difference:     -0.23%
#   p-value:        0.1211 ns
#
# monocyte:
#   Responders:     Mean = 19.94%, Median = 19.61%
#   Non-Responders: Mean = 20.08%, Median = 19.94%
#   Difference:     -0.14%
#   p-value:        0.1635 ns
#
# ...
