# %%
import helper_functions as hf
import pandas as pd

# Part 2 Initial Analysis - Data Overview

# Calculate cell frequencies using the database
print("First 30 rows of cell frequencies calculated using the database:")
df = hf.calculate_cell_frequencies()
print(df.iloc[0:30])

# Also calculate frequencies using pandas for database testing purposes
print("\nFirst 30 rows of cell frequencies calculated using pandas:")
df_pandas = hf.calculate_cell_frequencies_pandas()
print(df_pandas.iloc[0:30])

# Final Summary Table:
print("\nFinal summary table of cell frequencies:")
print(df)
df.to_csv("cell_frequencies_summary.csv", sep=",", index=False)
# Out:
# First 30 rows of cell frequencies calculated using the database:
#          sample  total_count  population  count  percentage
# 0   sample00000        93214      b_cell  10908       11.70
# 1   sample00000        93214  cd4_t_cell  20491       21.98
# 2   sample00000        93214  cd8_t_cell  24440       26.22
# 3   sample00000        93214    monocyte  23511       25.22
# 4   sample00000        93214     nk_cell  13864       14.87
# 5   sample00001       100824      b_cell   6777        6.72
# 6   sample00001       100824  cd4_t_cell  33459       33.19
# 7   sample00001       100824  cd8_t_cell  19407       19.25
# 8   sample00001       100824    monocyte  23011       22.82
# 9   sample00001       100824     nk_cell  18170       18.02
# 10  sample00002        92822      b_cell   9794       10.55
# 11  sample00002        92822  cd4_t_cell  24274       26.15
# 12  sample00002        92822  cd8_t_cell  22940       24.71
# 13  sample00002        92822    monocyte  18332       19.75
# ...

# %%
print(hf.bcell_average_in_melanoma_male_responders())
# Out:
# Average B cells for Melanoma male responders at time=0: 10206.15
# 10206.15
