# %%
import helper_functions as hf
import pandas as pd

hf.explore_baseline_miraclib_samples()
# Out:
# ...
# BASELINE ANALYSIS: Melanoma PBMC Samples (time=0) with Miraclib Treatment
# ...
#
# Total baseline samples found: 656
# Total unique subjects: 656
#
# 1. SAMPLES PER PROJECT:
# ----------------------------------------
#    prj1: 384 samples
#    prj3: 272 samples
#
# 2. SUBJECTS BY RESPONSE STATUS:
# ----------------------------------------
#    Non-Responders: 325 subjects
#    Responders: 331 subjects
#    Total: 656 subjects
#
# 3. SUBJECTS BY SEX:
# ----------------------------------------
#    Females: 312 subjects
#    Males: 344 subjects
#
# 4. RESPONSE BY SEX (CROSS-TABULATION):
# ----------------------------------------
# response  Non-Responders  Responders  Total
# sex
# Females              165         147    312
# Males                160         184    344
# Total                325         331    656
# (       sample_id subject_id  project_id project_name response sex
#  0    sample00000     sbj000           1         prj1       no   M
# ...
